# %% [markdown]
# <a href="https://colab.research.google.com/github/Existing-as-Tejas/RepoForML/blob/main/FirstNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy, matplotlib, cv2, torch, torchvision, sklearn
print("All core libraries imported successfully!")
# Out:
# All core libraries imported successfully!
